# %%
import pandas as pd

# %% [markdown]
# Dataset

# %%
data={'Palestine':'Palestine Pound', 'Ukraine':'Ukrainian hryvnia', 'Russia':'Ruble', 'Israel':'Shekel'}
data1={'iphone 13':650, 'iphone 14':850, 'iphone 15':1350}

# %%
countries=['Palestine','USA', 'Russia', 'Uzbekistan', 'Israel', 'Ukraine']

# %%
my_s1=pd.Series(data1)
my_s1
# Out:
# iphone 13     650
# iphone 14     850
# iphone 15    1350
# dtype: int64

# %%
my_series=pd.Series(data, index=countries)
my_series
# Out:
# Palestine       Palestine Pound
# USA                         NaN
# Russia                    Ruble
# Uzbekistan                  NaN
# Israel                   Shekel
# Ukraine       Ukrainian hryvnia
# dtype: object

# %%
my_series.name='Currency'
my_series.index.name='Country'
my_series
# Out:
# Country
# Palestine       Palestine Pound
# USA                         NaN
# Russia                    Ruble
# Uzbekistan                  NaN
# Israel                   Shekel
# Ukraine       Ukrainian hryvnia
# Name: Currency, dtype: object

# %%
my_series.isnull()
# Out:
# Country
# Palestine     False
# USA            True
# Russia        False
# Uzbekistan     True
# Israel        False
# Ukraine       False
# Name: Currency, dtype: bool

# %%
my_series.notnull()
# Out:
# Country
# Palestine      True
# USA           False
# Russia         True
# Uzbekistan    False
# Israel         True
# Ukraine        True
# Name: Currency, dtype: bool

# %%
my_series.values
# Out:
# array(['Palentine Pound', nan, 'Ruble', nan, 'Shekel',
#        'Ukrainian hryvnia'], dtype=object)

# %%
my_series.index
# Out:
# Index(['Palentine', 'USA', 'Russia', 'Uzbekistan', 'Israel', 'Ukraine'], dtype='object', name='Country')

# %%
my_s1[my_s1>800]
# Out:
# iphone 14     850
# iphone 15    1350
# dtype: int64

# %%
my_s1*3
# Out:
# iphone 13    1950
# iphone 14    2550
# iphone 15    4050
# dtype: int64

# %%
my_series*2
# Out:
# Country
# Palentine         Palentine PoundPalentine Pound
# USA                                          NaN
# Russia                                RubleRuble
# Uzbekistan                                   NaN
# Israel                              ShekelShekel
# Ukraine       Ukrainian hryvniaUkrainian hryvnia
# Name: Currency, dtype: object

# %%
my_series.hasnans
# Out:
# True

# %%
my_series.dtype
# Out:
# dtype('O')

# %%
my_s1.dtype
# Out:
# dtype('int64')

# %%
my_series.is_unique
# Out:
# False

# %%
my_s1.is_unique
# Out:
# True

# %%
my_series.shape
# Out:
# (6,)

# %%
my_s1.shape
# Out:
# (3,)

# %%
my_series.size
# Out:
# 6

# %%
my_s1.size
# Out:
# 3

# %%
my_series
# Out:
# Country
# Palentine       Palentine Pound
# USA                         NaN
# Russia                    Ruble
# Uzbekistan                  NaN
# Israel                   Shekel
# Ukraine       Ukrainian hryvnia
# Name: Currency, dtype: object

# %%
my_series.iloc[1]
# Out:
# nan

# %%
my_series.iloc[2]
# Out:
# 'Ruble'

# %%
my_s1
# Out:
# iphone 13     650
# iphone 14     850
# iphone 15    1350
# dtype: int64

# %%
my_s1[-1]
# Out:
# 1350

# %%
my_series.loc['Uzbekistan']
# Out:
# nan

# %%
my_s1.max()
# Out:
# 1350

# %%
my_s1.min()
# Out:
# 650

# %%
my_s1.mean()
# Out:
# 950.0

# %%
sas=pd.Series(['sister','father','brother','me'])
sas
# Out:
# 0     sister
# 1     father
# 2    brother
# 3         me
# dtype: object
