# %%
import pandas as pd

# %%
data={
    'Lenovo':['$1000', 'core i5', '16gb', '256gb', 'RTX'],
    'Samsung':['$960', 'core i5', '8gb', '256gb', 'RTX'],
    'MacBook':['$1100', 'core i7', '16gb', '512gb', 'RTX'],
    'LG':['$849', 'core i3', '8gb', '256gb', 'NVIDIA'],
    'Microsoft':['$930', 'core i7', '8gb', '256gb', 'NVIDIA'],
    'HP':['$1030', 'core i9', '16gb', '512gb', 'NVIDIA'],
    'Dell':['$880', 'core i3', '8gb', '256gb', 'RTX']
    }

# %%
df=pd.DataFrame(data, index=['PRICE', 'PROCESSOR', 'RAM', 'MEMORY', 'GRAPHIC CARD'])
df
# Out:
#                Lenovo  Samsung  MacBook       LG Microsoft       HP     Dell
# PRICE           $1000     $960    $1100     $849      $930    $1030     $880
# PROCESSOR     core i5  core i5  core i7  core i3   core i7  core i9  core i3
# RAM              16gb      8gb     16gb      8gb       8gb     16gb      8gb
# MEMORY          256gb    256gb    512gb    256gb     256gb    512gb    256gb
# GRAPHIC CARD      RTX      RTX      RTX   NVIDIA    NVIDIA   NVIDIA      RTX

# %%
df.head(2)
# Out:
#             Lenovo  Samsung  MacBook       LG Microsoft       HP     Dell
# PRICE        $1000     $960    $1100     $849      $930    $1030     $880
# PROCESSOR  core i5  core i5  core i7  core i3   core i7  core i9  core i3

# %%
df.shape
# Out:
# (5, 7)

# %%
df['Lenovo']
# Out:
# PRICE             $1000
# PROCESSOR       core i5
# RAM                16gb
# MEMORY            256gb
# GRAPHIC CARD        RTX
# Name: Lenovo, dtype: object

# %%
df.LG
# Out:
# PRICE              $849
# PROCESSOR       core i3
# RAM                 8gb
# MEMORY            256gb
# GRAPHIC CARD     NVIDIA
# Name: LG, dtype: object

# %%
df=pd.DataFrame(data, columns=['LG','Dell','Samsung','Microsoft','Lenovo','MacBook','HP', 'ASUS'], index=['PRICE', 'PROCESSOR', 'RAM', 'MEMORY', 'GRAPHIC CARD'])
df
# Out:
#                    LG     Dell  Samsung Microsoft   Lenovo  MacBook       HP  \
# PRICE            $849     $880     $960      $930    $1000    $1100    $1030
# PROCESSOR     core i3  core i3  core i5   core i7  core i5  core i7  core i9
# RAM               8gb      8gb      8gb       8gb     16gb     16gb     16gb
# MEMORY          256gb    256gb    256gb     256gb    256gb    512gb    512gb
# GRAPHIC CARD   NVIDIA      RTX      RTX    NVIDIA      RTX      RTX   NVIDIA
#
#              ASUS
# PRICE         NaN
# PROCESSOR     NaN
# RAM           NaN
# MEMORY        NaN
# GRAPHIC CARD  NaN

# %%
df.ASUS=0
df
# Out:
#                    LG     Dell  Samsung Microsoft   Lenovo  MacBook       HP  \
# PRICE            $849     $880     $960      $930    $1000    $1100    $1030
# PROCESSOR     core i3  core i3  core i5   core i7  core i5  core i7  core i9
# RAM               8gb      8gb      8gb       8gb     16gb     16gb     16gb
# MEMORY          256gb    256gb    256gb     256gb    256gb    512gb    512gb
# GRAPHIC CARD   NVIDIA      RTX      RTX    NVIDIA      RTX      RTX   NVIDIA
#
#               ASUS
# PRICE            0
# PROCESSOR        0
# RAM              0
# MEMORY           0
# GRAPHIC CARD     0

# %%
df['ASUS']=pd.Series(['$1200','core i9','32gb'], index=['PRICE','PROCESSOR','RAM'])
df
# Out:
#                    LG     Dell  Samsung Microsoft   Lenovo  MacBook       HP  \
# PRICE            $849     $880     $960      $930    $1000    $1100    $1030
# PROCESSOR     core i3  core i3  core i5   core i7  core i5  core i7  core i9
# RAM               8gb      8gb      8gb       8gb     16gb     16gb     16gb
# MEMORY          256gb    256gb    256gb     256gb    256gb    512gb    512gb
# GRAPHIC CARD   NVIDIA      RTX      RTX    NVIDIA      RTX      RTX   NVIDIA
#
#                  ASUS
# PRICE           $1200
# PROCESSOR     core i9
# RAM              32gb
# MEMORY            NaN
# GRAPHIC CARD      NaN

# %%
df.ASUS=['$1300','core i9','32gb','512gb','RTX + NVIDIA']
df
# Out:
#                    LG     Dell  Samsung Microsoft   Lenovo  MacBook       HP  \
# PRICE            $849     $880     $960      $930    $1000    $1100    $1030
# PROCESSOR     core i3  core i3  core i5   core i7  core i5  core i7  core i9
# RAM               8gb      8gb      8gb       8gb     16gb     16gb     16gb
# MEMORY          256gb    256gb    256gb     256gb    256gb    512gb    512gb
# GRAPHIC CARD   NVIDIA      RTX      RTX    NVIDIA      RTX      RTX   NVIDIA
#
#                       ASUS
# PRICE                $1300
# PROCESSOR          core i9
# RAM                   32gb
# MEMORY               512gb
# GRAPHIC CARD  RTX + NVIDIA

# %%
del df['LG']
df
# Out:
#                Dell  Samsung  Microsoft  Lenovo  MacBook     HP   ASUS
# PRICE         False    False      False   False    False  False  False
# PROCESSOR      True     True       True    True     True   True   True
# RAM            True     True       True   False    False  False   True
# MEMORY         True     True       True    True     True   True   True
# GRAPHIC CARD   True     True       True    True     True   True   True

# %%
data2={
    'Navoiy':{2001:370, 2002:363, 2003:359, 2004:401, 2005:389, 2006:384, 2007:377, 2008:382, 2009:351, 2010:374},
    'Toshkent':{2001:835, 2002:839, 2003:941, 2004:913, 2005:925, 2006:894, 2007:882, 2008:870, 2009:902, 2010:907}
}
df2=pd.DataFrame(data2)
df2
# Out:
#       Navoiy  Toshkent
# 2001     370       835
# 2002     363       839
# 2003     359       941
# 2004     401       913
# 2005     389       925
# 2006     384       894
# 2007     377       882
# 2008     382       870
# 2009     351       902
# 2010     374       907

# %%
df2.index.name='Yillar'
df2
# Out:
#         Navoiy  Toshkent
# Yillar
# 2001       370       835
# 2002       363       839
# 2003       359       941
# 2004       401       913
# 2005       389       925
# 2006       384       894
# 2007       377       882
# 2008       382       870
# 2009       351       902
# 2010       374       907

# %%
df2['Navoiy']
# Out:
# Yillar
# 2001    370
# 2002    363
# 2003    359
# 2004    401
# 2005    389
# 2006    384
# 2007    377
# 2008    382
# 2009    351
# 2010    374
# Name: Navoiy, dtype: int64

# %%
df2=pd.DataFrame(data2, index=[2001, 2002, 2003, 2004, 2005])
df2
# Out:
#       Navoiy  Toshkent
# 2001     370       835
# 2002     363       839
# 2003     359       941
# 2004     401       913
# 2005     389       925

# %%
transpose=df2.T
transpose
# Out:
#           2001  2002  2003  2004  2005
# Navoiy     370   363   359   401   389
# Toshkent   835   839   941   913   925

# %%
arr=df2.values

# %%
type(arr)
# Out:
# numpy.ndarray
