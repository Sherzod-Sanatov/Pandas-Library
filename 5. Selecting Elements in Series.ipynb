# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Dataset

# %%
data={'yillar':[2021,2020,2019,2018,2017,2016,2015,2010],
      'aholi soni': [33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
      'temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53],
      'zichlik':[79.77,78.68,77.53,76.34,75.13,73.9,72.71,67.03]}
df=pd.DataFrame(data, index=[21,20,19,18,17,16,15,10])
ind=[19,10,20,17,18,21,15,16]
ind.sort()
df.reindex(ind)
# Out:
#     yillar  aholi soni  temp  zichlik
# 10    2010        28.5  1.53    67.03
# 15    2015        30.9  1.64    72.71
# 16    2016        31.4  1.66    73.90
# 17    2017        31.9  1.65    75.13
# 18    2018        32.5  1.62    76.34
# 19    2019        32.9  1.56    77.53
# 20    2020        33.5  1.48    78.68
# 21    2021        33.9  1.54    79.77

# %% [markdown]
# to check data type, let's call columns in two ways

# %%
data=df[['aholi soni']]
print(data)
type(data)
# Out:
#     aholi soni
# 21        33.9
# 20        33.5
# 19        32.9
# 18        32.5
# 17        31.9
# 16        31.4
# 15        30.9
# 10        28.5
# pandas.core.frame.DataFrame

# %% [markdown]
# now it is 2nd way

# %%
data=df['aholi soni']
print(data)
print(type(data))
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: aholi soni, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# data is created, now it is turn to print any element from that data using index (row)

# %%
print(data[21])
type(data[21])
# Out:
# 33.9
# numpy.float64

# %% [markdown]
# data is created, now it is turn to print any element from that data using index (row)

# %%
print(data[[21]])
type(data[[21]])
# Out:
# 21    33.9
# Name: aholi soni, dtype: float64
# pandas.core.series.Series

# %% [markdown]
# printing elements using second method of indexing

# %%
data
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: aholi soni, dtype: float64

# %%
data[2:4]
# Out:
# 19    32.9
# 18    32.5
# Name: aholi soni, dtype: float64

# %%
data[[19,18]]
# Out:
# 19    32.9
# 18    32.5
# Name: aholi soni, dtype: float64

# %% [markdown]
# Indexes are not always numbers. They can be letters as well.

# %%
obj=pd.Series(np.arange(8), index=['a','b','c','d','f','e','h','i'])
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# f    4
# e    5
# h    6
# i    7
# dtype: int64

# %% [markdown]
# calling an element using letter index
#
# there is a difference between types of below codes

# %%
print(obj['h'])
type(obj['h'])
# Out:
# 6
# numpy.int64

# %%
print(obj[['h']])
type(obj[['h']])
# Out:
# h    6
# dtype: int64
# pandas.core.series.Series

# %%
print(obj['a':'d'])
type(obj['a':'d'])
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64
# pandas.core.series.Series

# %%
print(obj[[1,5]])
type(obj[[1,5]])
# Out:
# b    1
# e    5
# dtype: int64
# pandas.core.series.Series

# %%
print(obj[['b','e']])
type(obj[['b','e']])
# Out:
# b    1
# e    5
# dtype: int64
# pandas.core.series.Series

# %% [markdown]
# giving certain value to a piece of variable

# %%
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# f    4
# e    5
# h    6
# i    7
# dtype: int64

# %%
obj['b':'d']=12
obj
# Out:
# a     0
# b    12
# c    12
# d    12
# f     4
# e     5
# h     6
# i     7
# dtype: int64

# %% [markdown]
# Filtering

# %%
obj[obj>5]
# Out:
# b    12
# c    12
# d    12
# h     6
# i     7
# dtype: int64

# %%
obj[obj==12]
# Out:
# b    12
# c    12
# d    12
# dtype: int64
