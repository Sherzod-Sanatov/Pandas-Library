# %% [markdown]
# 1. Data Creation and Indexing:
#
# Generate a Series with 10 random integers from 1 to 100.
# Set a custom index of names to the series (e.g., fruits, countries).
# Access specific elements using both index positions and labels.
# Reverse the index order of the series.

# %%
import pandas as pd
import numpy as np
from pandas import Series

# %% [markdown]
# First class

# %%
data=np.random.randint(1,100,10)
data_pd=pd.Series(data)
data_pd
# Out:
# 0    26
# 1    12
# 2    10
# 3    43
# 4     4
# 5    89
# 6    48
# 7    45
# 8    25
# 9    44
# dtype: int64

# %%
data_pd.values
# Out:
# array([26, 12, 10, 43,  4, 89, 48, 45, 25, 44])

# %%
data_pd.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data_pd[9]
# Out:
# 44

# %%
data_pd[data_pd>45]
# Out:
# 5    89
# 6    48
# dtype: int64

# %%
cars=pd.Series(['toyota','mers','chevrolet','tesla'], index=['japan', 'germany','usa','elon'])
cars
# Out:
# japan         toyota
# germany         mers
# usa        chevrolet
# elon           tesla
# dtype: object

# %%
cars['elon']
# Out:
# 'tesla'

# %%
cars[['germany','japan','usa']]
# Out:
# germany         mers
# japan         toyota
# usa        chevrolet
# dtype: object

# %%
data_pd
# Out:
# 0    26
# 1    12
# 2    10
# 3    43
# 4     4
# 5    89
# 6    48
# 7    45
# 8    25
# 9    44
# dtype: int64

# %%
data_pd*2
# Out:
# 0     52
# 1     24
# 2     20
# 3     86
# 4      8
# 5    178
# 6     96
# 7     90
# 8     50
# 9     88
# dtype: int64

# %%
e=np.exp(data_pd)
e
# Out:
# 0    1.957296e+11
# 1    1.627548e+05
# 2    2.202647e+04
# 3    4.727839e+18
# 4    5.459815e+01
# 5    4.489613e+38
# 6    7.016736e+20
# 7    3.493427e+19
# 8    7.200490e+10
# 9    1.285160e+19
# dtype: float64

# %% [markdown]
# 2nd class

# %%
cars_dict={'Toyota':45000,'Lacetti':15000,'Mazda':23000,'Audi':34000}
cars_dict
# Out:
# {'Toyota': 45000, 'Lacetti': 15000, 'Mazda': 23000, 'Audi': 34000}

# %%
type(cars_dict)
# Out:
# dict

# %%
new_cars=Series(cars_dict)
new_cars
# Out:
# Toyota     45000
# Lacetti    15000
# Mazda      23000
# Audi       34000
# dtype: int64

# %%
type(new_cars)
# Out:
# pandas.core.series.Series

# %%
new_cars=Series({'Toyota':45000,'Lacetti':15000,'Mazda':23000,'Audi':34000})
new_cars
# Out:
# Toyota     45000
# Lacetti    15000
# Mazda      23000
# Audi       34000
# dtype: int64

# %%
'Malibu' in new_cars
# Out:
# False

# %%
'Audi' in new_cars
# Out:
# True

# %%
new_cars['Mazda']
# Out:
# 23000

# %%
cars_dict
# Out:
# {'Toyota': 45000, 'Lacetti': 15000, 'Mazda': 23000, 'Audi': 34000}

# %%
models=['Mazda','Lacetti','Audi','Ferrari','Toyota']

# %%
cars1=Series(cars_dict, index=models)
cars1
# Out:
# Mazda      23000.0
# Lacetti    15000.0
# Audi       34000.0
# Ferrari        NaN
# Toyota     45000.0
# dtype: float64
