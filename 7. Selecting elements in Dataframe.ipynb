# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating dataset

# %%
uzbekistan={20:33.5, 19:32.9, 18:32.5, 17:31.9, 16:31.4, 15:30.9}
kazakhistan={20:18.8, 19:18.5, 18:18.3, 17:18.1, 16:17.8, 15:17.6}
tajikistan={20:9.5, 19:9.3, 18:9.1, 17:8.9, 16:8.7, 15:8.5}
kirgizistan={20:6.5, 19:6.4, 18:6.3, 17:6.2, 16:6.1, 15:6.0}
turkmenistan={20:6.0, 19:5.9, 18:5.9, 17:5.8, 16:5.6, 15:5.6}

data={"Uzbekistan":uzbekistan,
      'Kazakhistan':kazakhistan,
      'Tajikistan':tajikistan,
      'Kirgizistan':kirgizistan,
      'Turkmenistan':turkmenistan}
df=pd.DataFrame(data)
df
# Out:
#     Uzbekistan  Kazakhistan  Tajikistan  Kirgizistan  Turkmenistan
# 20        33.5         18.8         9.5          6.5           6.0
# 19        32.9         18.5         9.3          6.4           5.9
# 18        32.5         18.3         9.1          6.3           5.9
# 17        31.9         18.1         8.9          6.2           5.8
# 16        31.4         17.8         8.7          6.1           5.6
# 15        30.9         17.6         8.5          6.0           5.6

# %% [markdown]
# converting to numpy array

# %%
df['Uzbekistan'].to_numpy()
# Out:
# array([33.5, 32.9, 32.5, 31.9, 31.4, 30.9])

# %% [markdown]
# calling two or more columns as dataframe

# %%
df[['Uzbekistan', 'Tajikistan']]
# Out:
#     Uzbekistan  Tajikistan
# 20        33.5         9.5
# 19        32.9         9.3
# 18        32.5         9.1
# 17        31.9         8.9
# 16        31.4         8.7
# 15        30.9         8.5

# %% [markdown]
# printing rows as it is done in lists in python

# %%
df[2:]
# Out:
#     Uzbekistan  Kazakhistan  Tajikistan  Kirgizistan  Turkmenistan
# 18        32.5         18.3         9.1          6.3           5.9
# 17        31.9         18.1         8.9          6.2           5.8
# 16        31.4         17.8         8.7          6.1           5.6
# 15        30.9         17.6         8.5          6.0           5.6

# %% [markdown]
# filtering

# %%
dfuz=df[['Uzbekistan']]
dfuz
# Out:
#     Uzbekistan
# 20        33.5
# 19        32.9
# 18        32.5
# 17        31.9
# 16        31.4
# 15        30.9

# %%
dfuz[dfuz['Uzbekistan']>32]
# Out:
#     Uzbekistan
# 20        33.5
# 19        32.9
# 18        32.5

# %%
dfuz[dfuz['Uzbekistan']<32]
# Out:
#     Uzbekistan
# 17        31.9
# 16        31.4
# 15        30.9

# %% [markdown]
# printing boolean data

# %%
df[['Uzbekistan']], [df['Uzbekistan']>31]
# Out:
# (    Uzbekistan
#  20        33.5
#  19        32.9
#  18        32.5
#  17        31.9
#  16        31.4
#  15        30.9,
#  [20     True
#   19     True
#   18     True
#   17     True
#   16     True
#   15    False
#   Name: Uzbekistan, dtype: bool])

# %% [markdown]
# Transposing
#
# Filtering

# %%
df1=df.transpose(copy=True)
df1
# Out:
#                 20    19    18    17    16    15
# Uzbekistan    33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhistan   18.8  18.5  18.3  18.1  17.8  17.6
# Tajikistan     9.5   9.3   9.1   8.9   8.7   8.5
# Kirgizistan    6.5   6.4   6.3   6.2   6.1   6.0
# Turkmenistan   6.0   5.9   5.9   5.8   5.6   5.6

# %%
df2=df.T
df2
# Out:
#                 20    19    18    17    16    15
# Uzbekistan    33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhistan   18.8  18.5  18.3  18.1  17.8  17.6
# Tajikistan     9.5   9.3   9.1   8.9   8.7   8.5
# Kirgizistan    6.5   6.4   6.3   6.2   6.1   6.0
# Turkmenistan   6.0   5.9   5.9   5.8   5.6   5.6

# %%
df3=df2[15]
df3
# Out:
# Uzbekistan      30.9
# Kazakhistan     17.6
# Tajikistan       8.5
# Kirgizistan      6.0
# Turkmenistan     5.6
# Name: 15, dtype: float64

# %%
df3[df2[15]<10]
# Out:
# Tajikistan      8.5
# Kirgizistan     6.0
# Turkmenistan    5.6
# Name: 15, dtype: float64
