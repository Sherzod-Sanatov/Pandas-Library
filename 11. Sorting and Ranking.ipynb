# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Sorting in Series

# %%
s1=pd.Series(range(4), index=['a','c','d','b'])
s1
# Out:
# a    0
# c    1
# d    2
# b    3
# dtype: int64

# %% [markdown]
# Soring by index

# %%
s1.sort_index()
# Out:
# a    0
# b    3
# c    1
# d    2
# dtype: int64

# %% [markdown]
# Sorting by values

# %%
s1.sort_values()
# Out:
# a    0
# c    1
# d    2
# b    3
# dtype: int64

# %%
df=pd.read_csv('/content/car data/CAR DETAILS FROM CAR DEKHO.csv')
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# Sorting in DataFrame

# %%
df.sort_index()
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                                      name  year  selling_price  km_driven  \
# 4339                     Renault KWID RXT  2016         225000      40000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# ...                                   ...   ...            ...        ...
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 0                           Maruti 800 AC  2007          60000      70000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.sort_index(axis=1)
# Out:
#         fuel  km_driven                                 name         owner  \
# 0     Petrol      70000                        Maruti 800 AC   First Owner
# 1     Petrol      50000             Maruti Wagon R LXI Minor   First Owner
# 2     Diesel     100000                 Hyundai Verna 1.6 SX   First Owner
# 3     Petrol      46000               Datsun RediGO T Option   First Owner
# 4     Diesel     141000                Honda Amaze VX i-DTEC  Second Owner
# ...      ...        ...                                  ...           ...
# 4335  Diesel      80000  Hyundai i20 Magna 1.4 CRDi (Diesel)  Second Owner
# 4336  Diesel      80000           Hyundai i20 Magna 1.4 CRDi  Second Owner
# 4337  Petrol      83000                  Maruti 800 AC BSIII  Second Owner
# 4338  Diesel      90000     Hyundai Creta 1.6 CRDi SX Option   First Owner
# 4339  Petrol      40000                     Renault KWID RXT   First Owner
#
#      seller_type  selling_price transmission  year
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#       year transmission  selling_price seller_type         owner  \
# 0     2007       Manual          60000  Individual   First Owner
# 1     2007       Manual         135000  Individual   First Owner
# 2     2012       Manual         600000  Individual   First Owner
# 3     2017       Manual         250000  Individual   First Owner
# 4     2014       Manual         450000  Individual  Second Owner
# ...    ...          ...            ...         ...           ...
# 4335  2014       Manual         409999  Individual  Second Owner
# 4336  2014       Manual         409999  Individual  Second Owner
# 4337  2009       Manual         110000  Individual  Second Owner
# 4338  2016       Manual         865000  Individual   First Owner
# 4339  2016       Manual         225000  Individual   First Owner
#
#                                      name  km_driven    fuel
# 0                           Maruti 800 AC      70000  Petrol
# 1                Maruti Wagon R LXI Minor      50000  Petrol
# ...

# %%
df.sort_values(by=['owner'])
# Out:
#                                          name  year  selling_price  km_driven  \
# 0                               Maruti 800 AC  2007          60000      70000
# 2565                     Honda Amaze S i-VTEC  2016         495000      11958
# 2566              Hyundai Creta 1.6 SX Option  2017        1025000       9000
# 2567                   Mahindra XUV500 W8 2WD  2015         750000      70000
# 2568  Renault Duster 85PS Diesel RxL Optional  2013         600000     120000
# ...                                       ...   ...            ...        ...
# 1941                     Honda City 1.5 EXI S  2004         105000     100000
# 1231   Tata Indica Vista Terra Quadrajet 1.3L  2011         140000      90000
# 3701                         Mahindra Xylo H4  2019         599000      15000
# 2429                          Toyota Etios GD  2011         350000     120000
# 173                    Hyundai Santro Xing XG  2006          70000     110000
#
# ...

# %%
df.sort_values(by=['fuel', 'transmission'], ascending=False)
# Out:
#                                         name  year  selling_price  km_driven  \
# 0                              Maruti 800 AC  2007          60000      70000
# 1                   Maruti Wagon R LXI Minor  2007         135000      50000
# 3                     Datsun RediGO T Option  2017         250000      46000
# 5                       Maruti Alto LX BSIII  2007         140000     125000
# 6                  Hyundai Xcent 1.2 Kappa S  2016         550000      25000
# ...                                      ...   ...            ...        ...
# 4001                Maruti Celerio Green VXI  2017         365000      78000
# 4063  Maruti Eeco 5 STR With AC Plus HTR CNG  2017         440000      14100
# 4076                   Maruti Ertiga VXI CNG  2014         595000      56600
# 4140  Maruti Eeco 5 STR With AC Plus HTR CNG  2018         409999      45000
# 4152            Hyundai Accent Executive CNG  2010         140000     110000
#
# ...

# %% [markdown]
# Ranking in DataFrame

# %%
df['rating']=df['selling_price'].rank()
df.sort_values(by='selling_price')
# Out:
#                                                    name  year  selling_price  \
# 2662                              Ford Ikon 1.6 ZXI NXt  2005          20000
# 2495                                  Ford Ikon 1.4 ZXi  2000          22000
# 2444                                      Maruti 800 EX  2004          30000
# 3206                                   OpelCorsa 1.4 GL  2002          35000
# 2849                                 Tata Nano Std BSII  2009          35000
# ...                                                 ...   ...            ...
# 1023                            BMW X5 xDrive 30d xLine  2019        4950000
# 2239                            BMW X5 xDrive 30d xLine  2019        4950000
# 3969            Mercedes-Benz GLS 2016-2020 350d 4MATIC  2016        5500000
# 89    Mercedes-Benz S-Class S 350d Connoisseurs Edition  2017        8150000
# 3872           Audi RS7 2015-2019 Sportback Performance  2016        8900000
#
# ...
